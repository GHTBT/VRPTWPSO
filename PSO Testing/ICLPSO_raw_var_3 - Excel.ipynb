# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from math import sqrt, inf, exp, ceil
import time
import xlsxwriter

# %% [markdown]
# ## Dataset

# %%
df = pd.DataFrame(columns=['Customer Number','X Coord','Y Coord','Demand', 'Ready Time', 'Due Time', 'Service Time','Vehicle Number','Vehicle Capacity'])
df.head()
# Out:
# Empty DataFrame
# Columns: [Customer Number, X Coord, Y Coord, Demand, Ready Time, Due Time, Service Time, Vehicle Number, Vehicle Capacity]
# Index: []

# %%
cust_num = 0
text_file = 'Data\\c102.txt'
with open(text_file, 'rt', newline='') as fo:
    for line_count, line in enumerate(fo, start=1):
        if line_count == 5:
            values = line.strip().split()
            vehicle_number = float(values[0])
            vehicle_capacity = float(values[1])
        if line_count >= 10:
            values = line.strip().split()
            df.loc[cust_num] = [float(values[0]),float(values[1]),float(values[2]),float(values[3]),float(values[4]),float(values[5]),float(values[6]),vehicle_number,vehicle_capacity]
            cust_num += 1
        else:
            pass

# %%
df.head(20)
# Out:
#     Customer Number  X Coord  Y Coord  Demand  Ready Time  Due Time  \
# 0               0.0     40.0     50.0     0.0         0.0    1236.0
# 1               1.0     45.0     68.0    10.0         0.0    1127.0
# 2               2.0     45.0     70.0    30.0         0.0    1125.0
# 3               3.0     42.0     66.0    10.0         0.0    1129.0
# 4               4.0     42.0     68.0    10.0       727.0     782.0
# 5               5.0     42.0     65.0    10.0         0.0    1130.0
# 6               6.0     40.0     69.0    20.0       621.0     702.0
# 7               7.0     40.0     66.0    20.0         0.0    1130.0
# 8               8.0     38.0     68.0    20.0       255.0     324.0
# 9               9.0     38.0     70.0    10.0       534.0     605.0
# 10             10.0     35.0     66.0    10.0       357.0     410.0
# 11             11.0     35.0     69.0    10.0       448.0     505.0
# 12             12.0     25.0     85.0    20.0         0.0    1107.0
# 13             13.0     22.0     75.0    30.0        30.0      92.0
# 14             14.0     22.0     85.0    10.0       567.0     620.0
# 15             15.0     20.0     80.0    40.0       384.0     429.0
# 16             16.0     20.0     85.0    40.0       475.0     528.0
# 17             17.0     18.0     75.0    20.0        99.0     148.0
# 18             18.0     15.0     75.0    20.0       179.0     254.0
# 19             19.0     15.0     80.0    10.0       278.0     345.0
#
#     Service Time  Vehicle Number  Vehicle Capacity
# 0            0.0            25.0             200.0
# 1           90.0            25.0             200.0
# 2           90.0            25.0             200.0
# 3           90.0            25.0             200.0
# 4           90.0            25.0             200.0
# 5           90.0            25.0             200.0
# 6           90.0            25.0             200.0
# 7           90.0            25.0             200.0
# 8           90.0            25.0             200.0
# 9           90.0            25.0             200.0
# 10          90.0            25.0             200.0
# 11          90.0            25.0             200.0
# 12          90.0            25.0             200.0
# 13          90.0            25.0             200.0
# 14          90.0            25.0             200.0
# 15          90.0            25.0             200.0
# 16          90.0            25.0             200.0
# 17          90.0            25.0             200.0
# 18          90.0            25.0             200.0
# 19          90.0            25.0             200.0

# %%
print(len(df))
# Out:
# 101

# %%
customer_number = 100

dep, = plt.plot(df.loc[0,'X Coord'], df.loc[0,'Y Coord'], 'kP', label='depot')
for customer_id in range(1,customer_number):
    custs, = plt.plot(df.loc[customer_id,'X Coord'], df.loc[customer_id,'Y Coord'], 'ro', label='customers')

plt.ylabel("y coordinate")
plt.xlabel("x coordinate")
plt.legend([dep, custs], ['depot', 'customers'], loc=1)
plt.show()

# %% [markdown]
# ## PSO

# %%
def Ecl_distance(p1, p2):
    return sqrt((p1.loc['X Coord']-p2.loc['X Coord'])**2+(p1.loc['Y Coord']-p2.loc['Y Coord'])**2)

# %%
test1=df.loc[1]
test2=df.loc[2]
print(Ecl_distance(test1,test2))
# Out:
# 2.0

# %%
def create_route_from_ind(data, individual):
    route = []
    subroute = []
    set_capacity = data.loc[1,'Vehicle Capacity']
    vehicle_load = 0
    previous_cust_id = 0
    elapsed_time = 0
    depot_due_time = data.loc[0,'Due Time']
    data_len = len(data)-1

    customer_indx = list(range(1, data_len))  # Exclude depot (0)
    sorted_indx = sorted(customer_indx, key=lambda i: individual[i-1], reverse=True)

    for cust_id in sorted_indx:
        demand = data.loc[cust_id,'Demand']
        updated_vehicle_load = vehicle_load + demand

        service_time = data.loc[cust_id,'Service Time']
        moving_time = Ecl_distance(data.loc[cust_id],data.loc[previous_cust_id])
        return_time = Ecl_distance(data.loc[cust_id],data.loc[0])
        updated_elapsed_time = elapsed_time + service_time + moving_time + return_time

        if(updated_vehicle_load <= set_capacity) and (updated_elapsed_time <= depot_due_time):
            subroute.append(cust_id)
            vehicle_load = updated_vehicle_load
            elapsed_time = updated_elapsed_time - return_time
        else:
            route.append(subroute)
            subroute = [cust_id]
            vehicle_load = demand
            moving_time = Ecl_distance(data.loc[cust_id],data.loc[0])
            elapsed_time = service_time + moving_time
        previos_cust_id = cust_id
    if(subroute):
        route.append(subroute)
    
    return route

# %%
def calculate_fitness(data, individual):

    transport_cost = 1.0  # cost of moving 1 vehicle for 1 unit
    vehicle_setup_cost = 1.0  # cost of adapting new vehicle
    wait_penalty = 0.5  # penalty for arriving too early
    delay_penalty = 3.0  # penalty for arriving too late

    route = create_route_from_ind(data, individual)
    total_cost = inf
    fitness = 0
    total_distance = 0
    max_vehicles_count = 25

    # checking if we have enough vehicles
    if len(route) <= max_vehicles_count:
        total_cost = 0
        for sub_route in route:
            sub_route_time_cost = 0
            sub_route_distance = 0
            elapsed_time = 0
            previous_cust_id = 0
            for cust_id in sub_route:
                # Calculate section distance
                distance = Ecl_distance(data.loc[cust_id],data.loc[previous_cust_id])
                # Update sub-route distance
                sub_route_distance = sub_route_distance + distance

                # Calculate time cost
                arrival_time = elapsed_time + distance

                waiting_time = max(data.loc[cust_id, 'Ready Time'] - arrival_time, 0)
                delay_time = max(arrival_time - data.loc[cust_id, 'Due Time'], 0)
                time_cost = wait_penalty * waiting_time + delay_penalty * delay_time

                # Update sub-route time cost
                sub_route_time_cost += time_cost

                # Update elapsed time
                service_time = data.loc[cust_id, 'Service Time']
                elapsed_time = arrival_time + service_time

                # Update last customer ID
                previous_cust_id = cust_id

            # Calculate transport cost
            distance_depot = Ecl_distance(data.loc[previous_cust_id],data.loc[0])
            sub_route_distance += distance_depot
            total_distance += sub_route_distance
            sub_route_transport_cost = vehicle_setup_cost + transport_cost * sub_route_distance
            # Obtain sub-route cost
            sub_route_cost = sub_route_time_cost + sub_route_transport_cost
            # Update total cost`
            total_cost += sub_route_cost

        fitness = total_cost

    return fitness, total_distance

# %%
class Particle:
    def __init__(self, data, num_dimension):
        self.position = []
        self.velocity = []
        self.pbest_position = self.position
        self.pbest_fitness = -1
        self.p_fitness = -1
        self.data = data
        self.raise_flag = 0
    
        for i in range(0, num_dimension):
            self.position.append(random.uniform(-5,5))
            self.velocity.append(random.uniform(-1,1))
    
    def evaluate(self):
        self.p_fitness = calculate_fitness(self.data, self.position)[0]
        if self.pbest_fitness == -1 or self.pbest_fitness < self.p_fitness:
            self.pbest_fitness = self.p_fitness
            self.pbest_position = self.position.copy()
            self.raise_flag = 0
        else:
            self.raise_flag = 1
    
    def update_velocity(self, d_num, gbest_position, iter_num, iter_max):
        #CLPSO velocity v_i = w*v_i + c*r_i*(pbest_fid - x_i)
        w_max = 0.9
        w_min = 0.4
        c = 1.49445

        r = random.uniform(0,1)
        g = iter_num
        G = iter_max
        w = w_max - (w_max - w_min)*(g/G)
        self.velocity[d_num] = w*self.velocity[d_num] + c*r*(gbest_position[d_num] - self.position[d_num])

    def update_position(self, d_num):
        self.position[d_num] = self.position[d_num] + self.velocity[d_num]

    def print(self):
        print(self.position, '', self.velocity)

# %%
class PSO():
    def __init__(self, data, num_dimensions, num_particles, max_iter):
        num_dimensions = num_dimensions
        self.gbest_fitness = -1
        self.gbest_position = []
        self.route = []
        self.distance = 0
        self.time = 0
        r = []
        flag = -1

        start_time = time.time()
        swarm = []
        for i in range(0,num_particles):
            swarm.append(Particle(data, num_dimensions))
        
        for i in range(max_iter):
            for j in range(0, num_particles):
                swarm[j].evaluate()
                enum_swarm = list(enumerate(swarm))
                sorted_swarm = sorted(enum_swarm, key=lambda x:x[1].p_fitness)
                index_after_sort = [idx for idx, val in sorted_swarm]

                find_i = 0
                sorted_i = -1

                for idx in index_after_sort:
                    if j == idx:
                        sorted_i = find_i
                    find_i +=1
                
                pci = sorted_i/(2*num_particles)
                n = 2 + round((ceil(num_particles/2)-2)/(num_particles*(sorted_i+1)))
                
                for k in range(0, num_dimensions):
                    r.append(random.uniform(0,0.5))

                exemplar = list(range(0, num_particles))
                exemplar.remove(j)
                random.shuffle(exemplar)

                if(flag != -1):
                    if(swarm[j].raise_flag == 1):
                        flag += 1
                    else:
                        flag = 0

                if(flag >= 7 or flag == -1):
                    best_fitness = inf
                    better_part_idx = -1
                    number_of_exemplar = n
                    for n in range(number_of_exemplar):
                        if(swarm[exemplar[n]].pbest_fitness < best_fitness):
                            best_fitness = swarm[exemplar[n]].pbest_fitness 
                            better_part_idx = n
                    exemplar_position = list(swarm[exemplar[better_part_idx]].position)
                    flag = 0
                    
                for d in range (0, num_dimensions):
                    if(r[d] < pci):
                        swarm[j].update_velocity(d_num=d, gbest_position = exemplar_position, iter_num=i, iter_max=max_iter)
                        swarm[j].update_position(d_num=d)
                    else:
                        swarm[j].update_velocity(d_num=d, gbest_position =swarm[j].pbest_position, iter_num=i, iter_max=max_iter)
                        swarm[j].update_position(d_num=d)

        for j in range(0, num_particles):
                swarm[j].evaluate()
                if swarm[j].p_fitness < self.gbest_fitness or self.gbest_fitness == -1:
                    self.gbest_position = list(swarm[j].position)
                    self.gbest_fitness = float(swarm[j].pbest_fitness)

        pos = self.gbest_position
        customer_indx = list(range(1, len(df)-1))  # Exclude depot (0)
        sorted_indx = sorted(customer_indx, key=lambda i: pos[i-1], reverse=True)
        self.route = create_route_from_ind(df, sorted_indx)
        self.time = time.time() - start_time
        self.gbest_fitness, self.distance = calculate_fitness(data, self.gbest_position)

        print(self.route)
        print('FINAL:')
        print(self.gbest_position)
        print(self.gbest_fitness)
        print()

    def result(self):
        return self.route, self.gbest_fitness, self.time, self.distance

# %% [markdown]
# ## Main

# %%
dataset_list = ['c101','c102','c103','c104','c105','c106','c107','c108', 'c109']

# %%
def num_to_col(n):
    result = ""
    while n > 0:
        n, r = divmod(n - 1, 26)
        result = chr(65 + r) + result
    return result

# %%
workbook = xlsxwriter.Workbook('ICLPSO_test.xlsx')

worksheet = workbook.add_worksheet()

center_format = workbook.add_format({'align':'center', 'valign':'vcenter', 'border':1, 'bold':1, 'font_size': 14})
title_format = workbook.add_format({'align':'center', 'valign':'vcenter', 'border':1, 'bold':1, 'font_size': 10})
data_format = workbook.add_format({'align':'center', 'valign':'vcenter', 'border':1, 'bold':0, 'font_size': 10})

for idx, dataset in enumerate(dataset_list):
    current_dataset = 'df_'+dataset
    #print(current_dataset)
    current_dataset = pd.DataFrame(columns=['Customer Number','X Coord','Y Coord','Demand', 'Ready Time', 'Due Time', 'Service Time','Vehicle Number','Vehicle Capacity'])
    current_dataset.head()
    cust_num = 0
    text_file = 'Data\\'+dataset+'.txt'
    with open(text_file, 'rt', newline='') as fo:
        for line_count, line in enumerate(fo, start=1):
            if line_count == 5:
                values = line.strip().split()
                vehicle_number = float(values[0])
                vehicle_capacity = float(values[1])
            if line_count >= 10:
                values = line.strip().split()
                current_dataset.loc[cust_num] = [float(values[0]),float(values[1]),float(values[2]),float(values[3]),float(values[4]),float(values[5]),float(values[6]),vehicle_number,vehicle_capacity]
                cust_num += 1
            else:
                pass
            
    pso = PSO(data = current_dataset, num_dimensions = len(current_dataset)-1, num_particles=25, max_iter=200)
    route, fitness, run_time, distance = pso.result()

    idx = idx*4 + 1
    row = 2
    col = idx
    worksheet.merge_range(str(num_to_col(idx+1)+'2:'+num_to_col(idx+4)+'2'),str(dataset), center_format)
    worksheet.write(row, col, 'Route', title_format)
    worksheet.write(row, col+1, 'Distance', title_format)
    worksheet.write(row, col+2, 'Fitness', title_format)
    worksheet.write(row, col+3, 'Run Time', title_format)

    row = 3
    worksheet.write(row, col, len(route), data_format)
    worksheet.write(row, col+1, distance, data_format)
    worksheet.write(row, col+2, fitness, data_format)
    worksheet.write(row, col+3, run_time, data_format)

workbook.close()
# Out:
# [[58, 9, 22, 10, 64, 66, 63, 8, 96], [54, 30, 84, 55, 47, 68, 35, 65, 56], [97, 78, 93, 51, 71, 32, 81, 3, 19], [52, 74, 73, 36, 1, 48, 6, 2, 37, 14], [16, 94, 43, 75, 80, 89, 12, 23, 31], [59, 72, 5, 26, 27, 98, 69, 46, 20, 24], [95, 53, 18, 44, 45, 33, 49, 76, 41, 4], [29, 17, 57, 79, 7, 62, 91, 60, 70], [61, 15, 28, 99, 82, 87, 90, 92, 11, 34], [25, 85, 83, 88, 77, 86, 21, 50, 42, 67], [39, 38, 40, 13]]
